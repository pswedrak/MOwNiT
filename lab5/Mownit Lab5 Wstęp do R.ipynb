# %%
library("ggplot2")

# %%
results = read.csv("times_julia.csv")

# %%
results
# Out:
#     size version time
# 1   100  naive   0.002443635
# 2   100  better  0.001217586
# 3   100  blas    0.000143515
# 4   100  naive   0.002450687
# 5   100  better  0.001329366
# 6   100  blas    0.000346622
# 7   100  naive   0.003545563
# 8   100  better  0.001218291
# 9   100  blas    0.000145631
# 10  100  naive   0.002447867
# 11  100  better  0.001326545
# 12  100  blas    0.000136110
# 13  100  naive   0.003310720
# 14  100  better  0.001374501
# 15  100  blas    0.000147394
# 16  100  naive   0.002464793
# 17  100  better  0.001267305
# 18  100  blas    0.000149862
# 19  100  naive   0.002941531
# 20  100  better  0.001237685
# 21  100  blas    0.000159030
# 22  100  naive   0.002441520
# 23  100  better  0.002134390
# 24  100  blas    0.000338865
# 25  100  naive   0.002484891
# 26  100  better  0.001236275
# 27  100  blas    0.000154093
# 28  100  naive   0.002464087
# 29  100  better  0.001258842
# 30  100  blas    0.000306071
# ... ...  ...     ...
# 271 1000 naive   4.7241115
# 272 1000 better  1.5427490
# 273 1000 blas    0.1050139
# 274 1000 naive   3.0852589
# 275 1000 better  1.4141094
# 276 1000 blas    0.1067773
# 277 1000 naive   3.1684983
# 278 1000 better  1.6012400
# 279 1000 blas    0.1317913
# 280 1000 naive   3.6843613
# 281 1000 better  1.4204625
# 282 1000 blas    0.1003618
# 283 1000 naive   3.2827039
# 284 1000 better  1.6775012
# 285 1000 blas    0.1804207
# 286 1000 naive   3.3065761
# 287 1000 better  1.6255960
# 288 1000 blas    0.1437873
# 289 1000 naive   3.5346790
# 290 1000 better  3.9706344
# 291 1000 blas    0.2497328
# 292 1000 naive   6.0018241
# 293 1000 better  1.8389091
# 294 1000 blas    0.1081240
# 295 1000 naive   4.5545902
# 296 1000 better  1.7554665
# 297 1000 blas    0.1757746
# 298 1000 naive   3.6527989
# 299 1000 better  1.4295142
# 300 1000 blas    0.1094445

# %%
avg_results = aggregate(time ~ size:version, data=results, FUN=mean)

# %%
avg_results
# Out:
#    size version time
# 1   100 better  0.0013600786
# 2   200 better  0.0105331956
# 3   300 better  0.0348329779
# 4   400 better  0.0805659080
# 5   500 better  0.1787720400
# 6   600 better  0.2701192094
# 7   700 better  0.4506271115
# 8   800 better  0.6786966854
# 9   900 better  1.3767831397
# 10 1000 better  1.8276182244
# 11  100 blas    0.0002027193
# 12  200 blas    0.0009964955
# 13  300 blas    0.0032763398
# 14  400 blas    0.0068592448
# 15  500 blas    0.0157745635
# 16  600 blas    0.0244877271
# 17  700 blas    0.0373862059
# 18  800 blas    0.0548602775
# 19  900 blas    0.1223304521
# 20 1000 blas    0.1411228168
# 21  100 naive   0.0026995294
# 22  200 naive   0.0224071816
# 23  300 naive   0.0739404832
# 24  400 naive   0.1803907280
# 25  500 naive   0.3673624856
# 26  600 naive   0.6202699707
# 27  700 naive   0.9998674867
# 28  800 naive   1.4822319522
# 29  900 naive   2.7293558501
# 30 1000 naive   3.8995402231

# %%
avg_results$sd = aggregate(time ~ size:version, data = results, FUN=sd)$time

# %%
avg_results
# Out:
#    size version time         sd
# 1   100 better  0.0013600786 2.771692e-04
# 2   200 better  0.0105331956 6.766562e-04
# 3   300 better  0.0348329779 2.014575e-03
# 4   400 better  0.0805659080 2.486488e-03
# 5   500 better  0.1787720400 1.755475e-02
# 6   600 better  0.2701192094 5.302172e-03
# 7   700 better  0.4506271115 2.264007e-02
# 8   800 better  0.6786966854 1.077455e-02
# 9   900 better  1.3767831397 7.566468e-01
# 10 1000 better  1.8276182244 7.665833e-01
# 11  100 blas    0.0002027193 8.897833e-05
# 12  200 blas    0.0009964955 2.320184e-04
# 13  300 blas    0.0032763398 7.234516e-04
# 14  400 blas    0.0068592448 8.133858e-04
# 15  500 blas    0.0157745635 2.958965e-03
# 16  600 blas    0.0244877271 1.518647e-03
# 17  700 blas    0.0373862059 1.859237e-03
# 18  800 blas    0.0548602775 2.131496e-03
# 19  900 blas    0.1223304521 6.175463e-02
# 20 1000 blas    0.1411228168 4.815800e-02
# 21  100 naive   0.0026995294 4.165737e-04
# 22  200 naive   0.0224071816 2.230216e-03
# 23  300 naive   0.0739404832 1.526504e-03
# 24  400 naive   0.1803907280 7.087418e-03
# 25  500 naive   0.3673624856 1.273506e-02
# 26  600 naive   0.6202699707 1.087739e-02
# 27  700 naive   0.9998674867 1.073495e-02
# 28  800 naive   1.4822319522 1.491953e-02
# 29  900 naive   2.7293558501 1.202588e+00
# 30 1000 naive   3.8995402231 9.248713e-01

# %%
ggplot(avg_results, aes(x = size, y = time, color = version)) + 
geom_point() + 
labs(y = "time [s]") +
geom_errorbar(aes(ymin=time-sd, ymax=time+sd))
# Out:
# plot without title

# %%
avg_results_naive <- avg_results[which(avg_results$version == "naive"), ]
fit_naive = lm(time ~ poly(size, 3, raw=TRUE),
        ,data=avg_results_naive)

# %%
avg_results_better <- avg_results[which(avg_results$version == "better"), ]
fit_better = lm(time ~ poly(size, 3, raw=TRUE),
        ,data=avg_results_better)

# %%
avg_results_blas <- avg_results[which(avg_results$version == "blas"), ]
fit_blas = lm(time ~ poly(size, 3, raw=TRUE),
        ,data=avg_results_blas)

# %%
ggplot(avg_results, aes(x = size, y = time, color = version)) + 
geom_point() + 
labs(y = "time [s]")
# Out:
# plot without title

# %%
newdata_naive = data.frame(size = seq(100,1000, length.out=901))
newdata_naive$version = "naive"
newdata_naive$time = predict(fit_naive, newdata)

# %%
newdata_better = data.frame(size = seq(100,1000, length.out=901))
newdata_better$version = "better"
newdata_better$time = predict(fit_better, newdata)

# %%
newdata_blas = data.frame(size = seq(100,1000, length.out=901))
newdata_blas$version = "blas"
newdata_blas$time = predict(fit_blas, newdata)

# %%
last_plot() + 
    geom_line(data=newdata_naive, 
    aes(x = size, y = time, color = version)
    ) + 
    geom_line(data=newdata_better, 
    aes(x = size, y = time, color = version)
    ) +
    geom_line(data=newdata_blas, 
    aes(x = size, y = time, color = version)
    )
# Out:
# plot without title
